# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
##saved from colab

# %%
data = pd.read_csv('sample_data/dataset.csv')

# %%
data.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %%
target_count = data.groupby("Target")['Target'].count()
labels = ["Drop", "Enrolled", "Graduate"]
plt.pie(target_count, labels=labels, autopct="%1.1f")
plt.title("Target Variable Analysis")
plt.show()

# %% [markdown]
# **Description for the marital status column:**
# 1 – single 2 – married 3 – widower 4 – divorced 5 – facto union 6 – legally separated

# %%
by_relationship_status = data.groupby(['Marital status', "Target"]).count()
by_relationship_status
# Out:
#                          Application mode  Application order  Course  \
# Marital status Target
# 1              Dropout               1184               1184    1184
#                Enrolled               720                720     720
#                Graduate              2015               2015    2015
# 2              Dropout                179                179     179
#                Enrolled                52                 52      52
#                Graduate               148                148     148
# 3              Dropout                  1                  1       1
#                Enrolled                 2                  2       2
#                Graduate                 1                  1       1
# 4              Dropout                 42                 42      42
#                Enrolled                16                 16      16
#                Graduate                33                 33      33
# ...

# %% [markdown]
# Might drop marital status variable lack of diversity in the different marital categories.

# %%
data = data.drop(columns=["Marital status"])

# %%
data.head()
# Out:
#    Application mode  Application order  Course  Daytime/evening attendance  \
# 0                 8                  5       2                           1
# 1                 6                  1      11                           1
# 2                 1                  5       5                           1
# 3                 8                  2      15                           1
# 4                12                  1       3                           0
#
#    Previous qualification  Nacionality  Mother's qualification  \
# 0                       1            1                      13
# 1                       1            1                       1
# 2                       1            1                      22
# 3                       1            1                      23
# 4                       1            1                      22
#
#    Father's qualification  Mother's occupation  Father's occupation  ...  \
# ...
